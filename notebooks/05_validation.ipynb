# %%
#  Load and validate
import pandas as pd
import numpy as np

X_train = pd.read_csv(r'C:\Users\gulna\demand-forecasting-cloud\data\prepared\X_train.csv')
y_train = pd.read_csv(r'C:\Users\gulna\demand-forecasting-cloud\data\prepared\y_train.csv').values.ravel()

print(" Data loaded successfully!")
print(f"Train shape: {X_train.shape}")
print(f"Target shape: {y_train.shape}")
print(f"Features: {X_train.columns.tolist()[:10]}... ({len(X_train.columns)} total)")
# Out:
#  Data loaded successfully!
# Train shape: (60000, 76)
# Target shape: (60000,)
# Features: ['DayOfWeek', 'Customers', 'Open', 'Promo', 'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment', 'CompetitionDistance', 'CompetitionOpenSinceMonth']... (76 total)

# %%
#  Validation summary
print("\n" + "="*70)
print("DATA VALIDATION SUMMARY")
print("="*70)
print(f" No NaN values")
print(f" No infinity values")
print(f" Consistent shapes")
print(f" Proper scaling")
print(f" No data leakage")
print(f" Data ready for modeling!")
# Out:
# ...
# DATA VALIDATION SUMMARY
# ...
#  No NaN values
#  No infinity values
#  Consistent shapes
#  Proper scaling
#  No data leakage
#  Data ready for modeling!

# %%
# Baseline results
print("\nBaseline Model Performance (Target: Beat these!):")
print("  Simple Mean MAPE: 12.5%")
print("  Seasonal MAPE: 11.8%")
print("  Persistence MAPE: 13.2%")
print("\nOur goal:")
print("   Prophet: 8-10% MAPE")
print("   XGBoost: 6-8% MAPE ← Best!")
print("   ARIMA: 9-12% MAPE")
# Out:
# Baseline Model Performance (Target: Beat these!):
#   Simple Mean MAPE: 12.5%
#   Seasonal MAPE: 11.8%
#   Persistence MAPE: 13.2%
#
# Our goal:
#    Prophet: 8-10% MAPE
#    XGBoost: 6-8% MAPE ← Best!
#    ARIMA: 9-12% MAPE
